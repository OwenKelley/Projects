# %%
'''
Owen Kelley

# 214 = number of files
'''
# Out:
# '\nOwen Kelley\n\n# 214 = number of files\n'

# %%
from Bio import SeqIO

import numpy as np
import pandas as pd
import tensorflow as tf
import keras as ks
from keras import layers
from sklearn.model_selection import train_test_split
from typing import Literal
import matplotlib.pyplot as plt
import seaborn as sns
import os, os.path


import zipfile
#with zipfile.ZipFile("./mitochondriaDNA.zip", 'r') as zip_ref:
#    zip_ref.extractall("dnaData")
# Out:
# C:\Users\owent\AppData\Roaming\Python\Python310\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING:tensorflow:From C:\Users\owent\AppData\Roaming\Python\Python310\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
######### Counts How Many Files in Folder ############
# Specify path to folder "./dnaData"
def howManyFiles(path):
    #import os, os.path
    # Prints number of files in given folder 
    return(len(os.listdir(path)))
######################################################

############# Adds nucleotides to list ###############
def recToList(arr, fastaFile):
    count=0
    #print("The new created array is : ", end=" ")
    it=0

    for rec in SeqIO.parse(fastaFile, "fasta"):
        count=count+1
        #print(count)

    while(it<len(rec.seq)):
        arr.append(rec.seq[it])
        #print(arr[it], end=" ")   
        it=it+1
        
    return arr

######################################################

# %%
path = "./dnaData"
numFiles = howManyFiles(path)

fileName=os.listdir("./dnaData")
file=np.array(fileName)

data = {}
df = pd.DataFrame(data, columns=[file.tolist()])
print(df)
#df['file'] = file.tolist()
###############################
#print(df)

nucleotides=[]

it=0
while(it<numFiles):
    newPath = "./dnaData/"+fileName[it]
    # Puts nucleotides into list
    recToList(nucleotides,newPath)




    nucleotides=[]
    it=it+1
'''
    itt=0
    while(itt<len(nucleotides)):
        df.at[itt,fileName[it]]=nucleotides #row/col
        itt=itt+1

        dfAdd={'(AH1.fa,)': }






            itt=0
    while(itt<len(nucleotides)):
        dfAdd={'('+fileName[it]+',)': nucleotides[itt]}
        #df.at[itt,fileName[it]]=nucleotides #row/col
        df.append(dfAdd, ignore_index = True)
        itt=itt+1

        dfAdd={}

'''

it=0
#print(df)
df.at[5,0]=0
df.iat[0,0]
#print(df.loc[5])
#print(df.iloc[0,1])
#df.at[0,'nucleotides']
# Out:
# Empty DataFrame
# ...

# %%
fileName=os.listdir("./dnaData")
testArry=[]
newPath = "./dnaData/"+fileName[0]
newPath2 = "./dnaData/"+fileName[1]

print(newPath2)

recToList(testArry,newPath)
print(testArry[0])
recToList(testArry,newPath2)

print("Print Start")
print(testArry[1])
print("Print Done")
# Out:
# ./dnaData/AH2.fa
# G
# Print Start
# A
# Print Done

# %%
fileName=os.listdir("./dnaData")
path = "./dnaData"
numFiles = howManyFiles(path)
arry=[]
arry1=[]

print(arry)
it=0
while(it<numFiles):
    newPath = "./dnaData/"+fileName[it]
    #print(newPath)
    recToList(arry,newPath)
    arry1.insert(it,arry)
    it=it+1

twoDArry=[fileName, arry1]
#print("This is arry[0]")
#print(arry1[0])
#print("This is arry[1]")
#print(arry1[1])
#print("Finished Printing")
# Out:
# []

# %%
nucleotides=[]
arry1=[]

nucleotides=["A","T","G","C"]

arry1.insert(0,nucleotides)

nucleotides=["G","G","G","C"]
arry1.insert(1,nucleotides)

nucleotides=["T","T","T","T"]
arry1.insert(2,nucleotides)
#print(arry1)

#arry.insert(0,arry1)


twoDArry=[fileName, arry1]
# Outer bracket represents filename
# twoDArry[0=filname | 1=nucleotide, # in list]

'''
Row x Column
Filename   []
Nucleotide []
'''
# Out:
# '\nRow x Column\nFilename   []\nNucleotide []\n'

# %%
import ctypes as ct
'''
fastaFile = "./dnaData/AH1.fa"

seq_dict = {rec.id : rec.seq for rec in SeqIO.parse(fastaFile, "fasta")}

for rec in SeqIO.parse(fastaFile, "fasta"):
    print(rec.seq) 
   
print(rec.seq[0])
len(rec.seq)
#print(seq_dict)
'''

recToList(arry1, "./dnaData/AH1.fa")
print(arry1)



it=0
while(it<numFiles):
    arryOfArry.insert(it,"A")   
    it=it+1
it=0


twoDArry=[fileName, arryOfArry]
print(twoDArry[0][0])

#print(pointerArry)
'''
pointToArry = []
#print("The new created array is : ", end=" ")
it=0
while(it<len(rec.seq)):
    arr.append(rec.seq[it])
    #print(arr[it], end=" ")   
    it=it+1
'''
# Out:
# [['A', 'T', 'G', 'C'], ['G', 'G', 'G', 'C'], ['T', 'T', 'T', 'T'], 'G', 'A', 'T', 'C', 'A', 'C', 'A', 'G', 'G', 'T', 'C', 'T', 'A', 'T', 'C', 'A', 'C', 'C', 'C', 'T', 'A', 'T', 'T', 'A', 'A', 'C', 'C', 'A', 'C', 'T', 'C', 'A', 'C', 'G', 'G', 'G', 'A', 'G', 'C', 'T', 'C', 'T', 'C', 'C', 'A', 'T', 'G', 'C', 'A', 'T', 'T', 'T', 'G', 'G', 'T', 'A', 'T', 'T', 'T', 'T', 'C', 'G', 'T', 'C', 'T', 'G', 'G', 'G', 'G', 'G', 'G', 'T', 'G', 'T', 'G', 'C', 'A', 'C', 'G', 'C', 'G', 'A', 'T', 'A', 'G', 'C', 'A', 'T', 'T', 'G', 'C', 'G', 'A', 'G', 'A', 'C', 'G', 'C', 'T', 'G', 'G', 'A', 'G', 'C', 'C', 'G', 'G', 'A', 'G', 'C', 'A', 'C', 'C', 'C', 'T', 'A', 'T', 'G', 'T', 'C', 'G', 'C', 'A', 'G', 'T', 'A', 'T', 'C', 'T', 'G', 'T', 'C', 'T', 'T', 'T', 'G', 'A', 'T', 'T', 'C', 'C', 'T', 'G', 'C', 'C', 'T', 'C', 'A', 'T', 'T', 'C', 'C', 'A', 'T', 'T', 'A', 'T', 'T', 'T', 'A', 'T', 'C', 'G', 'C', 'A', 'C', 'C', 'T', 'A', 'C', 'G', 'T', 'T', 'C', 'A', 'A', 'T', 'A', 'T', 'T', 'A', 'C', 'A', 'G', 'G', 'C', '
# ...

# %%
type(pointerArry)
#print(len(pointerArry))
#files=os.listdir("./dnaData")
#print(files)

# %%
import array as arr
a = arr.array('i', [1, 2, 3])
print("The new created array is : ", end=" ")
for i in range(0, 3):
    print(a[i], end=" ")
print()

a.append(4)
print()
for i in range(0,len(a)):
    print(a[i], end=" ")

# %%
p=0
# 214 = number of .fa files
'''
while(p<=213):
    print(rec.seq[p])
    p=p+1
'''
    
arr = []
print("The new created array is : ", end=" ")
it=0
while(it<=len(rec.seq)):
    arr.append(rec.seq[i])
    print(arr[i], end=" ")
